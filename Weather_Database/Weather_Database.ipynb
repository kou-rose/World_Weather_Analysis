# %%
# Import dependencies, time library
import pandas as pd
import numpy as np 
import time

# Import requests library.
import requests

# Import API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create set of random latitude/longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Adding latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create list for holding cities.
cities = []

# Identify nearest city for each latitude/longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If city unique, add to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print city count
len(cities)
# Out:
# 762

# %%
# Create empty list to hold the weather data.
city_data = []
# Print beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                        "Current Description": city_current})

# If an error is experienced, skip city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | klaksvik
# Processing Record 2 of Set 1 | sao joao da barra
# Processing Record 3 of Set 1 | vila velha
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | melilla
# Processing Record 6 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | laguna
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | chernyshevskiy
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | trinidad
# Processing Record 17 of Set 1 | raymond
# Processing Record 18 of Set 1 | ahvaz
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | gurupi
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | bang saphan
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | aranos
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | sabha
# Processing Record 30 of Set 1 | nadvoitsy
# Processing Record 31 of Set 1 | vila franca do campo
# Processing Record 32 of Set 1 | norman wells
# Processing Record 33 of Set 1 | verkhnevilyuysk
# Processing Record 34 of Set 1 | meulaboh
# Processing Record 35 of Set 1 | fortuna
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | morales
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | yershichi
# Processing Record 42 of Set 1 | acatic
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | bara
# Processing Record 45 of Set 1 | comodoro rivadavia
# Processing Record 46 of Set 1 | aswan
# Processing Record 47 of Set 1 | mandalgovi
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | lorengau
# Processing Record 1 of Set 2 | iguape
# Processing Record 2 of Set 2 | san miguelito
# Processing Record 3 of Set 2 | gazni
# City not found. Skipping...
# Processing Record 4 of Set 2 | kargasok
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | potters bar
# Processing Record 7 of Set 2 | thinadhoo
# Processing Record 8 of Set 2 | san cristobal
# Processing Record 9 of Set 2 | barroualie
# City not found. Skipping...
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | eureka
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | araouane
# Processing Record 16 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | tura
# Processing Record 22 of Set 2 | somerset
# Processing Record 23 of Set 2 | warrington
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | victoria
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | hay river
# Processing Record 29 of Set 2 | port augusta
# Processing Record 30 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 2 | neryungri
# Processing Record 32 of Set 2 | alofi
# Processing Record 33 of Set 2 | buenaventura
# Processing Record 34 of Set 2 | dingle
# Processing Record 35 of Set 2 | kafue
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | ystad
# Processing Record 38 of Set 2 | yangjiang
# Processing Record 39 of Set 2 | mecca
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | the valley
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | saint george
# Processing Record 47 of Set 2 | sabang
# Processing Record 48 of Set 2 | ixtapa
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | avera
# Processing Record 1 of Set 3 | kruisfontein
# Processing Record 2 of Set 3 | sinnamary
# Processing Record 3 of Set 3 | cockburn town
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 3 | nkan
# Processing Record 9 of Set 3 | dunedin
# Processing Record 10 of Set 3 | smederevska palanka
# Processing Record 11 of Set 3 | ramnagar
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | malanje
# Processing Record 15 of Set 3 | palembang
# Processing Record 16 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 3 | machali
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | gravdal
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | coahuayana
# Processing Record 22 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | kieta
# Processing Record 25 of Set 3 | san vicente de canete
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | baturaja
# Processing Record 28 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 3 | iwanai
# Processing Record 30 of Set 3 | san felipe
# Processing Record 31 of Set 3 | yulara
# Processing Record 32 of Set 3 | longonjo
# Processing Record 33 of Set 3 | caravelas
# Processing Record 34 of Set 3 | karatau
# Processing Record 35 of Set 3 | ancud
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | shache
# Processing Record 38 of Set 3 | sungaipenuh
# Processing Record 39 of Set 3 | mataura
# Processing Record 40 of Set 3 | kapoeta
# Processing Record 41 of Set 3 | tucuma
# Processing Record 42 of Set 3 | broome
# Processing Record 43 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 3 | biggar
# Processing Record 46 of Set 3 | bacolod
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | palimbang
# Processing Record 49 of Set 3 | biak
# Processing Record 50 of Set 3 | new norfolk
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | las vegas
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | jinotega
# Processing Record 5 of Set 4 | kawalu
# Processing Record 6 of Set 4 | hidalgotitlan
# Processing Record 7 of Set 4 | ribeira grande
# Processing Record 8 of Set 4 | wahpeton
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | saskylakh
# Processing Record 11 of Set 4 | puerto escondido
# Processing Record 12 of Set 4 | harper
# Processing Record 13 of Set 4 | ust-nera
# Processing Record 14 of Set 4 | visnes
# Processing Record 15 of Set 4 | cravo norte
# Processing Record 16 of Set 4 | umm lajj
# Processing Record 17 of Set 4 | ronne
# Processing Record 18 of Set 4 | pachino
# Processing Record 19 of Set 4 | buraydah
# Processing Record 20 of Set 4 | hilo
# Processing Record 21 of Set 4 | houma
# Processing Record 22 of Set 4 | ulladulla
# Processing Record 23 of Set 4 | margate
# Processing Record 24 of Set 4 | portland
# Processing Record 25 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 4 | senanga
# Processing Record 27 of Set 4 | anton
# Processing Record 28 of Set 4 | komsomolskiy
# Processing Record 29 of Set 4 | padang
# Processing Record 30 of Set 4 | santarem
# Processing Record 31 of Set 4 | ginda
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | kuryk
# Processing Record 34 of Set 4 | olafsvik
# Processing Record 35 of Set 4 | leningradskiy
# Processing Record 36 of Set 4 | deshna
# City not found. Skipping...
# Processing Record 37 of Set 4 | danjiangkou
# Processing Record 38 of Set 4 | manoel urbano
# Processing Record 39 of Set 4 | paamiut
# Processing Record 40 of Set 4 | brewster
# Processing Record 41 of Set 4 | isangel
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | yeppoon
# Processing Record 44 of Set 4 | boguchany
# Processing Record 45 of Set 4 | awbari
# Processing Record 46 of Set 4 | lovington
# Processing Record 47 of Set 4 | kirakira
# Processing Record 48 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 4 | flagstaff
# Processing Record 50 of Set 4 | batagay-alyta
# Processing Record 1 of Set 5 | atlantic city
# Processing Record 2 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 5 | trelew
# Processing Record 4 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 5 | saint-augustin
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | hovd
# Processing Record 8 of Set 5 | verkhoyansk
# Processing Record 9 of Set 5 | evensk
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | de-kastri
# Processing Record 13 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 5 | cheyenne
# Processing Record 15 of Set 5 | alekseyevsk
# Processing Record 16 of Set 5 | hami
# Processing Record 17 of Set 5 | dikson
# Processing Record 18 of Set 5 | kyra
# Processing Record 19 of Set 5 | nishihara
# Processing Record 20 of Set 5 | solnechnyy
# Processing Record 21 of Set 5 | morondava
# Processing Record 22 of Set 5 | bongandanga
# Processing Record 23 of Set 5 | phan thiet
# Processing Record 24 of Set 5 | waipawa
# Processing Record 25 of Set 5 | kavaratti
# Processing Record 26 of Set 5 | caiaponia
# Processing Record 27 of Set 5 | peniche
# Processing Record 28 of Set 5 | talnakh
# Processing Record 29 of Set 5 | carnarvon
# Processing Record 30 of Set 5 | sayyan
# Processing Record 31 of Set 5 | te anau
# Processing Record 32 of Set 5 | jalu
# Processing Record 33 of Set 5 | vao
# Processing Record 34 of Set 5 | codrington
# Processing Record 35 of Set 5 | buzmeyin
# Processing Record 36 of Set 5 | tuatapere
# Processing Record 37 of Set 5 | baoqing
# Processing Record 38 of Set 5 | quatre cocos
# Processing Record 39 of Set 5 | port hawkesbury
# Processing Record 40 of Set 5 | santa cruz
# Processing Record 41 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 5 | bonthe
# Processing Record 43 of Set 5 | longyearbyen
# Processing Record 44 of Set 5 | biltine
# Processing Record 45 of Set 5 | dehloran
# Processing Record 46 of Set 5 | canavieiras
# Processing Record 47 of Set 5 | adrar
# Processing Record 48 of Set 5 | iquique
# Processing Record 49 of Set 5 | fairbanks
# Processing Record 50 of Set 5 | port blair
# Processing Record 1 of Set 6 | bhainsdehi
# Processing Record 2 of Set 6 | gizo
# Processing Record 3 of Set 6 | rio tercero
# Processing Record 4 of Set 6 | bilma
# Processing Record 5 of Set 6 | half moon bay
# Processing Record 6 of Set 6 | gayeri
# Processing Record 7 of Set 6 | poum
# Processing Record 8 of Set 6 | manta
# Processing Record 9 of Set 6 | mackay
# Processing Record 10 of Set 6 | lakatoro
# Processing Record 11 of Set 6 | iturama
# Processing Record 12 of Set 6 | porto murtinho
# Processing Record 13 of Set 6 | buala
# Processing Record 14 of Set 6 | inirida
# Processing Record 15 of Set 6 | bose
# Processing Record 16 of Set 6 | yeniseysk
# Processing Record 17 of Set 6 | cap malheureux
# Processing Record 18 of Set 6 | vardo
# Processing Record 19 of Set 6 | olinda
# Processing Record 20 of Set 6 | svetlyy
# Processing Record 21 of Set 6 | machico
# Processing Record 22 of Set 6 | puerto maldonado
# Processing Record 23 of Set 6 | dongsheng
# Processing Record 24 of Set 6 | merauke
# Processing Record 25 of Set 6 | constitucion
# Processing Record 26 of Set 6 | scalea
# Processing Record 27 of Set 6 | hammerfest
# Processing Record 28 of Set 6 | pangkalanbuun
# Processing Record 29 of Set 6 | pangai
# Processing Record 30 of Set 6 | mahibadhoo
# Processing Record 31 of Set 6 | xai-xai
# Processing Record 32 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 6 | lavrentiya
# Processing Record 34 of Set 6 | ibra
# Processing Record 35 of Set 6 | nanortalik
# Processing Record 36 of Set 6 | dunda
# Processing Record 37 of Set 6 | xinzhou
# Processing Record 38 of Set 6 | ovsyanka
# Processing Record 39 of Set 6 | gornyak
# Processing Record 40 of Set 6 | velika kladusa
# Processing Record 41 of Set 6 | nelson bay
# Processing Record 42 of Set 6 | kontagora
# Processing Record 43 of Set 6 | lasalgaon
# Processing Record 44 of Set 6 | sao bras de alportel
# Processing Record 45 of Set 6 | miyako
# Processing Record 46 of Set 6 | alamosa
# Processing Record 47 of Set 6 | la ronge
# Processing Record 48 of Set 6 | baruun-urt
# Processing Record 49 of Set 6 | urumqi
# Processing Record 50 of Set 6 | itanhaem
# Processing Record 1 of Set 7 | xuanwu
# Processing Record 2 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 7 | severnoye
# Processing Record 4 of Set 7 | grootfontein
# Processing Record 5 of Set 7 | krasnoselkup
# Processing Record 6 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 7 | arman
# Processing Record 8 of Set 7 | sur
# Processing Record 9 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 7 | namatanai
# Processing Record 11 of Set 7 | wewak
# Processing Record 12 of Set 7 | villamontes
# Processing Record 13 of Set 7 | saravan
# Processing Record 14 of Set 7 | narsaq
# Processing Record 15 of Set 7 | korla
# Processing Record 16 of Set 7 | sawtell
# Processing Record 17 of Set 7 | whitehorse
# Processing Record 18 of Set 7 | balsas
# Processing Record 19 of Set 7 | fort nelson
# Processing Record 20 of Set 7 | hella
# Processing Record 21 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 7 | westport
# Processing Record 23 of Set 7 | nchelenge
# Processing Record 24 of Set 7 | roma
# Processing Record 25 of Set 7 | college
# Processing Record 26 of Set 7 | alabaster
# Processing Record 27 of Set 7 | smithers
# Processing Record 28 of Set 7 | inhambane
# Processing Record 29 of Set 7 | grants
# Processing Record 30 of Set 7 | plettenberg bay
# Processing Record 31 of Set 7 | udachnyy
# Processing Record 32 of Set 7 | port lincoln
# Processing Record 33 of Set 7 | barrow
# Processing Record 34 of Set 7 | vanavara
# Processing Record 35 of Set 7 | bubaque
# Processing Record 36 of Set 7 | challakere
# Processing Record 37 of Set 7 | buin
# Processing Record 38 of Set 7 | filadelfia
# Processing Record 39 of Set 7 | golden
# Processing Record 40 of Set 7 | leua
# Processing Record 41 of Set 7 | augusto correa
# Processing Record 42 of Set 7 | nazilli
# Processing Record 43 of Set 7 | novobirilyussy
# Processing Record 44 of Set 7 | cabo san lucas
# Processing Record 45 of Set 7 | tautira
# Processing Record 46 of Set 7 | bulgan
# Processing Record 47 of Set 7 | moyale
# Processing Record 48 of Set 7 | sitka
# Processing Record 49 of Set 7 | oistins
# Processing Record 50 of Set 7 | kifri
# Processing Record 1 of Set 8 | tocopilla
# Processing Record 2 of Set 8 | raichur
# Processing Record 3 of Set 8 | muros
# Processing Record 4 of Set 8 | yerbogachen
# Processing Record 5 of Set 8 | cesis
# Processing Record 6 of Set 8 | nioro
# Processing Record 7 of Set 8 | zhigansk
# Processing Record 8 of Set 8 | iqaluit
# Processing Record 9 of Set 8 | petrozavodsk
# Processing Record 10 of Set 8 | beidao
# Processing Record 11 of Set 8 | hendaye
# Processing Record 12 of Set 8 | lalganj
# Processing Record 13 of Set 8 | dudinka
# Processing Record 14 of Set 8 | saint anthony
# Processing Record 15 of Set 8 | carnduff
# Processing Record 16 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 8 | hiriyur
# Processing Record 18 of Set 8 | luanda
# Processing Record 19 of Set 8 | virapandi
# City not found. Skipping...
# Processing Record 20 of Set 8 | grand gaube
# Processing Record 21 of Set 8 | asau
# Processing Record 22 of Set 8 | hofn
# Processing Record 23 of Set 8 | pisco
# Processing Record 24 of Set 8 | gobabis
# Processing Record 25 of Set 8 | san patricio
# Processing Record 26 of Set 8 | ballina
# Processing Record 27 of Set 8 | sault sainte marie
# Processing Record 28 of Set 8 | carmen
# Processing Record 29 of Set 8 | kropotkin
# Processing Record 30 of Set 8 | kangaatsiaq
# Processing Record 31 of Set 8 | pucallpa
# Processing Record 32 of Set 8 | kohtla-jarve
# Processing Record 33 of Set 8 | geraldton
# Processing Record 34 of Set 8 | buchanan
# Processing Record 35 of Set 8 | stephenville
# Processing Record 36 of Set 8 | porgera
# Processing Record 37 of Set 8 | salisbury
# Processing Record 38 of Set 8 | lagoa
# Processing Record 39 of Set 8 | matagami
# Processing Record 40 of Set 8 | novorzhev
# Processing Record 41 of Set 8 | beringovskiy
# Processing Record 42 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 8 | leku
# Processing Record 44 of Set 8 | mahanje
# Processing Record 45 of Set 8 | torbay
# Processing Record 46 of Set 8 | vilani
# Processing Record 47 of Set 8 | monforte de lemos
# Processing Record 48 of Set 8 | cidreira
# Processing Record 49 of Set 8 | mamlyutka
# Processing Record 50 of Set 8 | macau
# Processing Record 1 of Set 9 | karratha
# Processing Record 2 of Set 9 | kriel
# Processing Record 3 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 9 | sept-iles
# Processing Record 5 of Set 9 | ceamurlia de jos
# Processing Record 6 of Set 9 | batticaloa
# Processing Record 7 of Set 9 | hirara
# Processing Record 8 of Set 9 | luderitz
# Processing Record 9 of Set 9 | chiredzi
# Processing Record 10 of Set 9 | sola
# Processing Record 11 of Set 9 | newcastle
# Processing Record 12 of Set 9 | boralday
# Processing Record 13 of Set 9 | erenhot
# Processing Record 14 of Set 9 | dukat
# Processing Record 15 of Set 9 | salalah
# Processing Record 16 of Set 9 | vallenar
# Processing Record 17 of Set 9 | chililabombwe
# Processing Record 18 of Set 9 | menongue
# Processing Record 19 of Set 9 | valdivia
# Processing Record 20 of Set 9 | bud
# Processing Record 21 of Set 9 | boca do acre
# Processing Record 22 of Set 9 | beinamar
# Processing Record 23 of Set 9 | ambon
# Processing Record 24 of Set 9 | ballstad
# City not found. Skipping...
# Processing Record 25 of Set 9 | luena
# Processing Record 26 of Set 9 | sandwick
# Processing Record 27 of Set 9 | vila
# Processing Record 28 of Set 9 | sao miguel
# Processing Record 29 of Set 9 | berlevag
# Processing Record 30 of Set 9 | alto araguaia
# Processing Record 31 of Set 9 | chute-aux-outardes
# Processing Record 32 of Set 9 | ribnitz-damgarten
# Processing Record 33 of Set 9 | pionerskiy
# Processing Record 34 of Set 9 | cayenne
# Processing Record 35 of Set 9 | liancheng
# Processing Record 36 of Set 9 | hilton head island
# Processing Record 37 of Set 9 | albina
# Processing Record 38 of Set 9 | mount isa
# Processing Record 39 of Set 9 | ulaangom
# Processing Record 40 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 9 | luganville
# Processing Record 42 of Set 9 | ambilobe
# Processing Record 43 of Set 9 | san rafael
# Processing Record 44 of Set 9 | rapid city
# Processing Record 45 of Set 9 | port hedland
# Processing Record 46 of Set 9 | kungurtug
# Processing Record 47 of Set 9 | pitkyaranta
# Processing Record 48 of Set 9 | ajdabiya
# Processing Record 49 of Set 9 | bolshoy lug
# Processing Record 50 of Set 9 | belaya gora
# Processing Record 1 of Set 10 | kulhudhuffushi
# Processing Record 2 of Set 10 | vangaindrano
# Processing Record 3 of Set 10 | namwala
# Processing Record 4 of Set 10 | mehamn
# Processing Record 5 of Set 10 | chalmette
# Processing Record 6 of Set 10 | owando
# Processing Record 7 of Set 10 | sangar
# Processing Record 8 of Set 10 | liku
# Processing Record 9 of Set 10 | boende
# Processing Record 10 of Set 10 | wauwatosa
# Processing Record 11 of Set 10 | guerrero negro
# Processing Record 12 of Set 10 | zaraza
# Processing Record 13 of Set 10 | hailar
# Processing Record 14 of Set 10 | mercedes
# Processing Record 15 of Set 10 | meadow lake
# Processing Record 16 of Set 10 | murakami
# Processing Record 17 of Set 10 | hambantota
# Processing Record 18 of Set 10 | bolshaya irba
# City not found. Skipping...
# Processing Record 19 of Set 10 | flinders
# Processing Record 20 of Set 10 | okandja
# City not found. Skipping...
# Processing Record 21 of Set 10 | tabou
# Processing Record 22 of Set 10 | raudeberg
# Processing Record 23 of Set 10 | makakilo city
# Processing Record 24 of Set 10 | yalvac
# Processing Record 25 of Set 10 | baherden
# Processing Record 26 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 10 | calama
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 10 | smoky lake
# Processing Record 31 of Set 10 | prince albert
# Processing Record 32 of Set 10 | aksu
# Processing Record 33 of Set 10 | tagusao
# Processing Record 34 of Set 10 | sada
# Processing Record 35 of Set 10 | alta floresta
# Processing Record 36 of Set 10 | dakar
# Processing Record 37 of Set 10 | qui nhon
# Processing Record 38 of Set 10 | domoni
# Processing Record 39 of Set 10 | lima
# Processing Record 40 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 41 of Set 10 | vung tau
# Processing Record 42 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 10 | saint-georges
# Processing Record 44 of Set 10 | bloomfield
# Processing Record 45 of Set 10 | araripe
# Processing Record 46 of Set 10 | sfantu gheorghe
# Processing Record 47 of Set 10 | cartagena
# Processing Record 48 of Set 10 | tete
# Processing Record 49 of Set 10 | gigmoto
# Processing Record 50 of Set 10 | kasamwa
# Processing Record 1 of Set 11 | verkhnyaya toyma
# Processing Record 2 of Set 11 | farmington
# Processing Record 3 of Set 11 | west wendover
# Processing Record 4 of Set 11 | coquimbo
# Processing Record 5 of Set 11 | ahipara
# Processing Record 6 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 11 | kupang
# Processing Record 8 of Set 11 | bhola
# Processing Record 9 of Set 11 | mapanas
# Processing Record 10 of Set 11 | nemuro
# Processing Record 11 of Set 11 | sidi ali
# Processing Record 12 of Set 11 | mamakan
# Processing Record 13 of Set 11 | barcelona
# Processing Record 14 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 11 | inverell
# Processing Record 16 of Set 11 | burica
# City not found. Skipping...
# Processing Record 17 of Set 11 | labuhan
# Processing Record 18 of Set 11 | pitimbu
# Processing Record 19 of Set 11 | candido mendes
# Processing Record 20 of Set 11 | ndele
# Processing Record 21 of Set 11 | calbuco
# Processing Record 22 of Set 11 | rawson
# Processing Record 23 of Set 11 | ulagan
# Processing Record 24 of Set 11 | pemangkat
# Processing Record 25 of Set 11 | naldurg
# Processing Record 26 of Set 11 | shubarshi
# Processing Record 27 of Set 11 | odweyne
# Processing Record 28 of Set 11 | khairagarh
# Processing Record 29 of Set 11 | severobaykalsk
# Processing Record 30 of Set 11 | alice springs
# Processing Record 31 of Set 11 | winsum
# Processing Record 32 of Set 11 | bilibino
# Processing Record 33 of Set 11 | tucupita
# Processing Record 34 of Set 11 | belchatow
# Processing Record 35 of Set 11 | wakkanai
# Processing Record 36 of Set 11 | saldanha
# Processing Record 37 of Set 11 | esmeraldas
# Processing Record 38 of Set 11 | fort morgan
# Processing Record 39 of Set 11 | lazarev
# Processing Record 40 of Set 11 | saint-pierre
# Processing Record 41 of Set 11 | lerwick
# Processing Record 42 of Set 11 | balykshi
# Processing Record 43 of Set 11 | sioux lookout
# Processing Record 44 of Set 11 | truckee
# Processing Record 45 of Set 11 | sindou
# Processing Record 46 of Set 11 | bouna
# Processing Record 47 of Set 11 | sao filipe
# Processing Record 48 of Set 11 | vasterhaninge
# Processing Record 49 of Set 11 | borama
# City not found. Skipping...
# Processing Record 50 of Set 11 | vipperod
# Processing Record 1 of Set 12 | nouadhibou
# Processing Record 2 of Set 12 | belmonte
# Processing Record 3 of Set 12 | bonavista
# Processing Record 4 of Set 12 | severo-yeniseyskiy
# Processing Record 5 of Set 12 | high level
# Processing Record 6 of Set 12 | thunder bay
# Processing Record 7 of Set 12 | richards bay
# Processing Record 8 of Set 12 | kutum
# Processing Record 9 of Set 12 | port hardy
# Processing Record 10 of Set 12 | kedougou
# Processing Record 11 of Set 12 | mamu kanjan
# Processing Record 12 of Set 12 | srednekolymsk
# Processing Record 13 of Set 12 | markova
# Processing Record 14 of Set 12 | osoyoos
# Processing Record 15 of Set 12 | sharan
# Processing Record 16 of Set 12 | hualmay
# Processing Record 17 of Set 12 | aripuana
# Processing Record 18 of Set 12 | nurota
# Processing Record 19 of Set 12 | tiznit
# Processing Record 20 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 21 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 12 | daru
# Processing Record 23 of Set 12 | bemidji
# Processing Record 24 of Set 12 | glazunovka
# Processing Record 25 of Set 12 | kasempa
# Processing Record 26 of Set 12 | aklavik
# Processing Record 27 of Set 12 | rabo de peixe
# Processing Record 28 of Set 12 | awjilah
# Processing Record 29 of Set 12 | byron bay
# Processing Record 30 of Set 12 | loughrea
# Processing Record 31 of Set 12 | de aar
# Processing Record 32 of Set 12 | sakakah
# Processing Record 33 of Set 12 | svetlaya
# Processing Record 34 of Set 12 | manado
# Processing Record 35 of Set 12 | ravenna
# Processing Record 36 of Set 12 | naliya
# Processing Record 37 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 12 | bathsheba
# Processing Record 39 of Set 12 | rapar
# Processing Record 40 of Set 12 | harboore
# Processing Record 41 of Set 12 | sao borja
# Processing Record 42 of Set 12 | ilovlya
# Processing Record 43 of Set 12 | chumikan
# Processing Record 44 of Set 12 | los llanos de aridane
# Processing Record 45 of Set 12 | hattiesburg
# Processing Record 46 of Set 12 | mwene-ditu
# Processing Record 47 of Set 12 | shar
# Processing Record 48 of Set 12 | rabak
# Processing Record 49 of Set 12 | emirdag
# Processing Record 50 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 1 of Set 13 | dahuk
# Processing Record 2 of Set 13 | manaure
# Processing Record 3 of Set 13 | batemans bay
# Processing Record 4 of Set 13 | sherlovaya gora
# Processing Record 5 of Set 13 | kahului
# Processing Record 6 of Set 13 | strezhevoy
# Processing Record 7 of Set 13 | chongwe
# Processing Record 8 of Set 13 | katsuura
# Processing Record 9 of Set 13 | swan hill
# Processing Record 10 of Set 13 | soyo
# Processing Record 11 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 13 | shubarkuduk
# Processing Record 13 of Set 13 | san jeronimo
# Processing Record 14 of Set 13 | kudahuvadhoo
# Processing Record 15 of Set 13 | kushima
# Processing Record 16 of Set 13 | turukhansk
# Processing Record 17 of Set 13 | tingi
# Processing Record 18 of Set 13 | garowe
# Processing Record 19 of Set 13 | amga
# Processing Record 20 of Set 13 | uyuni
# Processing Record 21 of Set 13 | naze
# Processing Record 22 of Set 13 | zhangye
# Processing Record 23 of Set 13 | pacific grove
# Processing Record 24 of Set 13 | poli
# Processing Record 25 of Set 13 | balabac
# Processing Record 26 of Set 13 | manacapuru
# Processing Record 27 of Set 13 | gairo
# Processing Record 28 of Set 13 | dasoguz
# Processing Record 29 of Set 13 | chimbote
# Processing Record 30 of Set 13 | estelle
# Processing Record 31 of Set 13 | sao gabriel da cachoeira
# Processing Record 32 of Set 13 | debre tabor
# Processing Record 33 of Set 13 | tyulgan
# Processing Record 34 of Set 13 | bileca
# Processing Record 35 of Set 13 | mareeba
# Processing Record 36 of Set 13 | nurobod
# Processing Record 37 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 13 | carroll
# Processing Record 39 of Set 13 | mangai
# Processing Record 40 of Set 13 | hasaki
# Processing Record 41 of Set 13 | orlik
# Processing Record 42 of Set 13 | sisimiut
# Processing Record 43 of Set 13 | balkanabat
# Processing Record 44 of Set 13 | ostrovnoy
# Processing Record 45 of Set 13 | souillac
# Processing Record 46 of Set 13 | taoudenni
# Processing Record 47 of Set 13 | concepcion del oro
# Processing Record 48 of Set 13 | arequipa
# Processing Record 49 of Set 13 | mbekenyera
# Processing Record 50 of Set 13 | malakal
# Processing Record 1 of Set 14 | pangnirtung
# Processing Record 2 of Set 14 | kuliyapitiya
# Processing Record 3 of Set 14 | kloulklubed
# Processing Record 4 of Set 14 | kavieng
# Processing Record 5 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 6 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 14 | yangambi
# Processing Record 8 of Set 14 | freeport
# Processing Record 9 of Set 14 | cooma
# Processing Record 10 of Set 14 | maragogi
# Processing Record 11 of Set 14 | rio gallegos
# Processing Record 12 of Set 14 | ormara
# Processing Record 13 of Set 14 | ereymentau
# Processing Record 14 of Set 14 | hamilton
# Processing Record 15 of Set 14 | makokou
# Processing Record 16 of Set 14 | atar
# Processing Record 17 of Set 14 | fallon
# Processing Record 18 of Set 14 | karema
# Processing Record 19 of Set 14 | stantsionno-oyashinskiy
# Processing Record 20 of Set 14 | mayumba
# Processing Record 21 of Set 14 | viedma
# Processing Record 22 of Set 14 | yar-sale
# Processing Record 23 of Set 14 | kendari
# Processing Record 24 of Set 14 | kollumerland
# City not found. Skipping...
# Processing Record 25 of Set 14 | san juan de abajo
# Processing Record 26 of Set 14 | ongandjera
# Processing Record 27 of Set 14 | guanica
# Processing Record 28 of Set 14 | vostok
# Processing Record 29 of Set 14 | devils lake
# Processing Record 30 of Set 14 | bati
# Processing Record 31 of Set 14 | yumen
# Processing Record 32 of Set 14 | shimoda
# Processing Record 33 of Set 14 | vestmannaeyjar
# Processing Record 34 of Set 14 | lykhivka
# Processing Record 35 of Set 14 | zhoucheng
# Processing Record 36 of Set 14 | santiago de cao
# Processing Record 37 of Set 14 | santiago de chuco
# Processing Record 38 of Set 14 | ascension
# Processing Record 39 of Set 14 | puerto carreno
# Processing Record 40 of Set 14 | butere
# Processing Record 41 of Set 14 | camacha
# Processing Record 42 of Set 14 | port macquarie
# Processing Record 43 of Set 14 | guane
# Processing Record 44 of Set 14 | iglesias
# Processing Record 45 of Set 14 | amahai
# Processing Record 46 of Set 14 | burnie
# Processing Record 47 of Set 14 | salinopolis
# Processing Record 48 of Set 14 | nivala
# Processing Record 49 of Set 14 | tommot
# Processing Record 50 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 15 | taltal
# Processing Record 2 of Set 15 | san miguel
# Processing Record 3 of Set 15 | moussoro
# Processing Record 4 of Set 15 | acapulco
# Processing Record 5 of Set 15 | lompoc
# Processing Record 6 of Set 15 | ndouci
# City not found. Skipping...
# Processing Record 7 of Set 15 | mitu
# Processing Record 8 of Set 15 | ginir
# Processing Record 9 of Set 15 | minsk
# Processing Record 10 of Set 15 | hongjiang
# Processing Record 11 of Set 15 | san joaquin
# Processing Record 12 of Set 15 | carndonagh
# Processing Record 13 of Set 15 | sens
# Processing Record 14 of Set 15 | buriti alegre
# Processing Record 15 of Set 15 | maniitsoq
# Processing Record 16 of Set 15 | teya
# Processing Record 17 of Set 15 | huarmey
# Processing Record 18 of Set 15 | lata
# Processing Record 19 of Set 15 | bogatyye saby
# Processing Record 20 of Set 15 | mayo
# Processing Record 21 of Set 15 | suda
# Processing Record 22 of Set 15 | xinyu
# Processing Record 23 of Set 15 | kindu
# Processing Record 24 of Set 15 | basti
# Processing Record 25 of Set 15 | zhigalovo
# Processing Record 26 of Set 15 | bluefield
# Processing Record 27 of Set 15 | san policarpo
# Processing Record 28 of Set 15 | kalabo
# Processing Record 29 of Set 15 | nicoya
# Processing Record 30 of Set 15 | chippewa falls
# Processing Record 31 of Set 15 | chanthaburi
# Processing Record 32 of Set 15 | moron
# Processing Record 33 of Set 15 | male
# Processing Record 34 of Set 15 | villarrobledo
# Processing Record 35 of Set 15 | grindavik
# Processing Record 36 of Set 15 | victor harbor
# Processing Record 37 of Set 15 | abu samrah
# Processing Record 38 of Set 15 | saint-leu
# Processing Record 39 of Set 15 | luwuk
# Processing Record 40 of Set 15 | hobyo
# Processing Record 41 of Set 15 | agadez
# Processing Record 42 of Set 15 | presidencia roque saenz pena
# Processing Record 43 of Set 15 | dodge city
# Processing Record 44 of Set 15 | wajid
# Processing Record 45 of Set 15 | santiago
# Processing Record 46 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 47 of Set 15 | namibe
# Processing Record 48 of Set 15 | benghazi
# Processing Record 49 of Set 15 | khani
# Processing Record 50 of Set 15 | mount gambier
# Processing Record 1 of Set 16 | tornio
# Processing Record 2 of Set 16 | baykit
# Processing Record 3 of Set 16 | gao
# Processing Record 4 of Set 16 | caxito
# Processing Record 5 of Set 16 | carauari
# Processing Record 6 of Set 16 | zhanatas
# City not found. Skipping...
# Processing Record 7 of Set 16 | mukilteo
# Processing Record 8 of Set 16 | kemijarvi
# Processing Record 9 of Set 16 | tignere
# Processing Record 10 of Set 16 | glencoe
# Processing Record 11 of Set 16 | bolitoc
# Processing Record 12 of Set 16 | yurla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
# Convert to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Klaksvik      FO  62.2266   -6.5890     50.92        88
# 1  Sao Joao Da Barra      BR -21.6403  -41.0511     70.14        86
# 2         Vila Velha      BR -20.3297  -40.2925     66.94        94
# 3          Upernavik      GL  72.7868  -56.1549     46.22        65
# 4            Melilla      ES  35.2937   -2.9383     75.58        88
# 5       Punta Arenas      CL -53.1500  -70.9167     24.91        86
# 6             Laguna      US  38.4210 -121.4238     81.34        45
# 7       Ponta Do Sol      PT  32.6667  -17.1000     68.72        81
# 8               Lebu      CL -37.6167  -73.6500     43.09        85
# 9         Chokurdakh      RU  70.6333  147.9167     53.38        58
#
#    Cloudiness  Wind Speed Current Description
# 0          99       13.82     overcast clouds
# 1          62       19.01       broken clouds
# 2          70        8.12       broken clouds
# 3           9        2.37           clear sky
# 4          75        2.30       broken clouds
# 5          40       13.80    scattered clouds
# 6           0        7.43           clear sky
# 7           9        2.01           clear sky
# 8          19        3.20          few clouds
# 9          98       10.18     overcast clouds

# %%
# Create output file (CSV).
output_data_file = "Weather_Data/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
